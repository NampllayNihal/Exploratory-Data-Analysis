# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Cleaned_Titanic_Dataset.csv")

# Preview the data
print(df.head())

# Summary stats
print(df.describe(include='all'))

# Data types
print(df.dtypes)

# Missing values
print(df.isnull().sum())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    0 -0.565736      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  0.663861      1
# 2                             Heikkinen, Miss. Laina    1 -0.258337      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  0.433312      1
# 4                           Allen, Mr. William Henry    0  0.433312      0
#
#    Parch            Ticket      Fare  Embarked_Q  Embarked_S
# 0      0         A/5 21171 -0.502445       False        True
# 1      0          PC 17599  0.786845       False       False
# 2      0  STON/O2. 3101282 -0.488854       False        True
# 3      0            113803  0.420730       False        True
# 4      0            373450 -0.486337       False        True
#         PassengerId    Survived      Pclass                 Name         Sex  \
# count    891.000000  891.000000  891.000000                  891  891.000000
# unique          NaN         NaN         NaN                  891         NaN
# top             NaN         NaN         NaN  Dooley, Mr. Patrick         NaN
# freq            NaN         NaN         NaN                    1         NaN
# mean     446.000000    0.383838    2.308642                  NaN    0.352413
# std      257.353842    0.486592    0.836071                  NaN    0.477990
# min        1.000000    0.000000    1.000000                  NaN    0.000000
# 25%      223.500000    0.000000    2.000000                  NaN    0.000000
# 50%      446.000000    0.000000    3.000000                  NaN    0.000000
# 75%      668.500000    1.000000    3.000000                  NaN    1.000000
# max      891.000000    1.000000    3.000000                  NaN    1.000000
#
#                  Age       SibSp       Parch  Ticket          Fare Embarked_Q  \
# count   8.910000e+02  891.000000  891.000000     891  8.910000e+02        891
# unique           NaN         NaN         NaN     681           NaN          2
# top              NaN         NaN         NaN  347082           NaN      False
# freq             NaN         NaN         NaN       7           NaN        814
# mean    2.392400e-16    0.523008    0.381594     NaN  2.791133e-17        NaN
# std     1.000562e+00    1.102743    0.806057     NaN  1.000562e+00        NaN
# min    -2.224156e+00    0.000000    0.000000     NaN -6.484217e-01        NaN
# 25%    -5.657365e-01    0.000000    0.000000     NaN -4.891482e-01        NaN
# 50%    -1.046374e-01    0.000000    0.000000     NaN -3.573909e-01        NaN
# 75%     4.333115e-01    1.000000    0.000000     NaN -2.424635e-02        NaN
# max     3.891554e+00    8.000000    6.000000     NaN  9.667167e+00        NaN
#
#        Embarked_S
# count         891
# unique          2
# top          True
# freq          646
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked_Q        bool
# Embarked_S        bool
# dtype: object
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for age
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# Boxplot for fare
sns.boxplot(x=df['Fare'])
plt.title('Fare Boxplot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
# Select only numeric columns before calculating correlation
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Pairplot
sns.pairplot(df[['Age', 'Fare', 'Survived']], hue='Survived')
plt.show()

# %%
# Survival by gender
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival Count by Gender")
plt.show()

# Survival by passenger class
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival Count by Class")
plt.show()
